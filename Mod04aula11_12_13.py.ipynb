# %%
from IPython.display import display, HTML
import pandas as pd
import seaborn as sns

dado_hist={
    'Empresa 1':[4,9,6,5],
    'Empresa 2':[9, 6, 4, 15],
    'Empresa 3':[6, 4, 2, 25],
    'Empresa 4':[4, 2, 4, 35],
    'Empresa 5':[2, 4, 9, 45]
    }

df = pd.DataFrame(dado_hist)

print(df)

display(HTML(df.to_html()))

dfa= df.head(2)

display(HTML(dfa.to_html()))

dft= df.tail(2)

display(HTML(dft.to_html()))

cm = sns.light_palette("y",as_cmap = True)

s = df.style.background_gradient(cmap = cm)
display(s)
# Out:
#    Empresa 1  Empresa 2  Empresa 3  Empresa 4  Empresa 5
# 0          4          9          6          4          2
# 1          9          6          4          2          4
# 2          6          4          2          4          9
# 3          5         15         25         35         45
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Empresa 1</th>
#       <th>Empresa 2</th>
#       <th>Empresa 3</th>
#       <th>Empresa 4</th>
#       <th>Empresa 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>9</td>
#       <td>6</td>
#       <td>4</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9</td>
#       <td>6</td>
#       <td>4</td>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>4</td>
#       <td>2</td>
#       <td>4</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5</td>
#       <td>15</td>
#       <td>25</td>
#       <td>35</td>
#       <td>45</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Empresa 1</th>
#       <th>Empresa 2</th>
#       <th>Empresa 3</th>
#       <th>Empresa 4</th>
#       <th>Empresa 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>9</td>
#       <td>6</td>
#       <td>4</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9</td>
#       <td>6</td>
#       <td>4</td>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Empresa 1</th>
#       <th>Empresa 2</th>
#       <th>Empresa 3</th>
#       <th>Empresa 4</th>
#       <th>Empresa 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>4</td>
#       <td>2</td>
#       <td>4</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5</td>
#       <td>15</td>
#       <td>25</td>
#       <td>35</td>
#       <td>45</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b2e54_row0_col0, #T_b2e54_row0_col4, #T_b2e54_row1_col3, #T_b2e54_row2_col1, #T_b2e54_row2_col2 {
#   background-color: #f2f2dd;
#   color: #000000;
# }
# #T_b2e54_row0_col1 {
#   background-color: #dbdb79;
#   color: #000000;
# }
# #T_b2e54_row0_col2 {
#   background-color: #e9e9b7;
#   color: #000000;
# }
# #T_b2e54_row0_col3, #T_b2e54_row2_col3 {
#   background-color: #efefd0;
#   color: #000000;
# }
# #T_b2e54_row1_col0, #T_b2e54_row3_col1, #T_b2e54_row3_col2, #T_b2e54_row3_col3, #T_b2e54_row3_col4 {
#   background-color: #bfbf00;
#   color: #000000;
# }
# #T_b2e54_row1_col1 {
#   background-color: #e9e9b5;
#   color: #000000;
# }
# #T_b2e54_row1_col2 {
#   background-color: #eeeeca;
#   color: #000000;
# }
# #T_b2e54_row1_col4 {
#   background-color: #f0f0d4;
#   color: #000000;
# }
# #T_b2e54_row2_col0 {
#   background-color: #dede85;
#   color: #000000;
# }
# #T_b2e54_row2_col4 {
#   background-color: #eaeaba;
#   color: #000000;
# }
# #T_b2e54_row3_col0 {
#   background-color: #e8e8b1;
#   color: #000000;
# }
# </style>
# <table id="T_b2e54_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Empresa 1</th>
#       <th class="col_heading level0 col1" >Empresa 2</th>
#       <th class="col_heading level0 col2" >Empresa 3</th>
#       <th class="col_heading level0 col3" >Empresa 4</th>
#       <th class="col_heading level0 col4" >Empresa 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2e54_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2e54_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_b2e54_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_b2e54_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_b2e54_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_b2e54_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b2e54_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b2e54_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_b2e54_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_b2e54_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_b2e54_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_b2e54_row1_col4" class="data row1 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b2e54_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b2e54_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_b2e54_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_b2e54_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_b2e54_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_b2e54_row2_col4" class="data row2 col4" >9</td>
#     </tr>
#     <tr>
#       <th id="T_b2e54_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b2e54_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_b2e54_row3_col1" class="data row3 col1" >15</td>
#       <td id="T_b2e54_row3_col2" class="data row3 col2" >25</td>
#       <td id="T_b2e54_row3_col3" class="data row3 col3" >35</td>
#       <td id="T_b2e54_row3_col4" class="data row3 col4" >45</td>
#     </tr>
#   </tbody>
# </table>

# %%
import seaborn as sns

df.loc[:4].style.background_gradient(cmap='hot')
# há vários tipos de cmap: vitidis; magma, hot etc.
# Out:
# <style type="text/css">
# #T_04cbf_row0_col0, #T_04cbf_row0_col4, #T_04cbf_row1_col3, #T_04cbf_row2_col1, #T_04cbf_row2_col2 {
#   background-color: #0b0000;
#   color: #f1f1f1;
# }
# #T_04cbf_row0_col1 {
#   background-color: #ff3c00;
#   color: #f1f1f1;
# }
# #T_04cbf_row0_col2 {
#   background-color: #7e0000;
#   color: #f1f1f1;
# }
# #T_04cbf_row0_col3, #T_04cbf_row2_col3 {
#   background-color: #320000;
#   color: #f1f1f1;
# }
# #T_04cbf_row1_col0, #T_04cbf_row3_col1, #T_04cbf_row3_col2, #T_04cbf_row3_col3, #T_04cbf_row3_col4 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_04cbf_row1_col1 {
#   background-color: #830000;
#   color: #f1f1f1;
# }
# #T_04cbf_row1_col2 {
#   background-color: #440000;
#   color: #f1f1f1;
# }
# #T_04cbf_row1_col4 {
#   background-color: #270000;
#   color: #f1f1f1;
# }
# #T_04cbf_row2_col0 {
#   background-color: #ff1700;
#   color: #f1f1f1;
# }
# #T_04cbf_row2_col4 {
#   background-color: #760000;
#   color: #f1f1f1;
# }
# #T_04cbf_row3_col0 {
#   background-color: #900000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_04cbf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Empresa 1</th>
#       <th class="col_heading level0 col1" >Empresa 2</th>
#       <th class="col_heading level0 col2" >Empresa 3</th>
#       <th class="col_heading level0 col3" >Empresa 4</th>
#       <th class="col_heading level0 col4" >Empresa 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04cbf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04cbf_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_04cbf_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_04cbf_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_04cbf_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_04cbf_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_04cbf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04cbf_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_04cbf_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_04cbf_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_04cbf_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_04cbf_row1_col4" class="data row1 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_04cbf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04cbf_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_04cbf_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_04cbf_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_04cbf_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_04cbf_row2_col4" class="data row2 col4" >9</td>
#     </tr>
#     <tr>
#       <th id="T_04cbf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04cbf_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_04cbf_row3_col1" class="data row3 col1" >15</td>
#       <td id="T_04cbf_row3_col2" class="data row3 col2" >25</td>
#       <td id="T_04cbf_row3_col3" class="data row3 col3" >35</td>
#       <td id="T_04cbf_row3_col4" class="data row3 col4" >45</td>
#     </tr>
#   </tbody>
# </table>
