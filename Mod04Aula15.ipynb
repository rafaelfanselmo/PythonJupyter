# %%
import pandas as pd

dado_hist = {
    'Empresa 1':[4,9,6,5],
    'Empresa 2':[9,6,4,15],
    'Empresa 3':[6,4,2,25],
    'Empresa 4':[4,2,4,35],
    'Empresa 5':[2,4,9,45]
}

df = pd.DataFrame(dado_hist)

df.loc[0,'Empresa 2'] = -9
df.loc[1,'Empresa 2'] = -6
df.loc[2,'Empresa 2'] = -4
print(df)
df.style.bar(subset=['Empresa 1','Empresa 2'],align='mid',color=['#d65f5f','#5fba7d'])
# Out:
#    Empresa 1  Empresa 2  Empresa 3  Empresa 4  Empresa 5
# 0          4         -9          6          4          2
# 1          9         -6          4          2          4
# 2          6         -4          2          4          9
# 3          5         15         25         35         45
# <style type="text/css">
# #T_e3d12_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 44.4%, transparent 44.4%);
# }
# #T_e3d12_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 37.5%, transparent 37.5%);
# }
# #T_e3d12_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
# }
# #T_e3d12_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.5%, #d65f5f 12.5%, #d65f5f 37.5%, transparent 37.5%);
# }
# #T_e3d12_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 66.7%, transparent 66.7%);
# }
# #T_e3d12_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 20.8%, #d65f5f 20.8%, #d65f5f 37.5%, transparent 37.5%);
# }
# #T_e3d12_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 55.6%, transparent 55.6%);
# }
# #T_e3d12_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 37.5%, #5fba7d 37.5%, #5fba7d 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_e3d12_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Empresa 1</th>
#       <th class="col_heading level0 col1" >Empresa 2</th>
#       <th class="col_heading level0 col2" >Empresa 3</th>
#       <th class="col_heading level0 col3" >Empresa 4</th>
#       <th class="col_heading level0 col4" >Empresa 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3d12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3d12_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_e3d12_row0_col1" class="data row0 col1" >-9</td>
#       <td id="T_e3d12_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_e3d12_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_e3d12_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e3d12_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3d12_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_e3d12_row1_col1" class="data row1 col1" >-6</td>
#       <td id="T_e3d12_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_e3d12_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_e3d12_row1_col4" class="data row1 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e3d12_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3d12_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_e3d12_row2_col1" class="data row2 col1" >-4</td>
#       <td id="T_e3d12_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_e3d12_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_e3d12_row2_col4" class="data row2 col4" >9</td>
#     </tr>
#     <tr>
#       <th id="T_e3d12_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3d12_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_e3d12_row3_col1" class="data row3 col1" >15</td>
#       <td id="T_e3d12_row3_col2" class="data row3 col2" >25</td>
#       <td id="T_e3d12_row3_col3" class="data row3 col3" >35</td>
#       <td id="T_e3d12_row3_col4" class="data row3 col4" >45</td>
#     </tr>
#   </tbody>
# </table>
