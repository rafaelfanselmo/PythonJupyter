# %%
import pandas as pd
import io
import requests


#somente com esse link funcionou
#url = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
url = "https://covid.ourworldindata.org/data/ecdc/total_cases.csv"
s = requests.get(url).content
df = pd.read_csv(io.StringIO(s.decode('utf8')))
df
#dft = df.copy()
#dft = dft.transpose() #faz a trasnposição da tabela
#dft = dft.dropna() # dropa os elementos que não números
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21892/3124826198.py in <module>
#       8 url = "https://covid.ourworldindata.org/data/ecdc/total_cases.csv"
#       9 s = requests.get(url).content
# ---> 10 df = pd.read_csv(io.StringIO(s.decode('utf8')))
#      11 df
#      12 #dft = df.copy()
#
# c:\users\usrafa\appdata\local\programs\python\python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
dft = df.copy()
dft = dft.transpose()
dft
# Out:
#                                               0            1       \
# iso_code                                         AFG          AFG
# continent                                       Asia         Asia
# location                                 Afghanistan  Afghanistan
# date                                      2020-02-24   2020-02-25
# total_cases                                      5.0          5.0
# ...                                              ...          ...
# human_development_index                        0.511        0.511
# excess_mortality_cumulative_absolute             NaN          NaN
# excess_mortality_cumulative                      NaN          NaN
# excess_mortality                                 NaN          NaN
# excess_mortality_cumulative_per_million          NaN          NaN
#
#                                               2            3       \
# iso_code                                         AFG          AFG
# ...

# %%
dft = dft.dropna()
dft
# Out:
#                0            1            2            3            4       \
# iso_code          AFG          AFG          AFG          AFG          AFG
# location  Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# date       2020-02-24   2020-02-25   2020-02-26   2020-02-27   2020-02-28
#
#                5            6            7            8            9       \
# iso_code          AFG          AFG          AFG          AFG          AFG
# location  Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# date       2020-02-29   2020-03-01   2020-03-02   2020-03-03   2020-03-04
#
#           ...      181681      181682      181683      181684      181685  \
# iso_code  ...         ZWE         ZWE         ZWE         ZWE         ZWE
# location  ...    Zimbabwe    Zimbabwe    Zimbabwe    Zimbabwe    Zimbabwe
# date      ...  2022-04-16  2022-04-17  2022-04-18  2022-04-19  2022-04-20
#
#               181686      181687      181688      181689      181690
# ...

# %%
import matplotlib.pyplot as plt

x  = df["date"]
y1 = df["Italy"]
y2 = df["Spain"]

plt.plot(x,y1, label='Itália')
plt.plot(x,y2, label='Espanha')
plt.legend()
plt.title("Evolução de casos confirmados")
plt.show()
